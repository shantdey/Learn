# %%
import math

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import statsmodels.formula.api as sm

# %%
from statsmodels.tsa import tsatools, stattools

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
from statsmodels.graphics import tsaplots

# %%
amtrak_df = pd.read_csv('Amtrak.csv')

# %%
amtrak_df.head()
# Out:
#     Month  Ridership
# 0  Jan-91   1708.917
# 1  Feb-91   1620.586
# 2  Mar-91   1972.715
# 3  Apr-91   1811.665
# 4  May-91   1974.964

# %%
amtrak_df.describe()
# Out:
#          Ridership
# count   159.000000
# mean   1822.197208
# std     181.636034
# min    1360.852000
# 25%    1698.564500
# 50%    1831.049000
# 75%    1966.957500
# max    2223.349000

# %%
amtrak_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Month      159 non-null    object
#  1   Ridership  159 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 2.6+ KB

# %%
amtrak_df.dtypes
# Out:
# Month         object
# Ridership    float64
# dtype: object

# %% [raw]
# def fix_date(date_str):
#         if '-' in date_str:
#                 parts = date_str.split('-')
#                 if len(parts) == 2 and parts[1] == '00':
#                             return f"{parts[0]} 2000"
#         return date_str
# # Apply the function to the 'date' column
# amtrak_df['Month'] = amtrak_df['Month'].apply(fix_date)

# %%
amtrak_df['Month'] = pd.to_datetime(amtrak_df['Month'])
amtrak_df['Month'] = pd.to_datetime(amtrak_df['Month']) 
amtrak_df.set_index('Month', inplace=True)
# Out:
# /tmp/ipykernel_11861/1680073187.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   amtrak_df['Month'] = pd.to_datetime(amtrak_df['Month'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File parsing.pyx:684, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: day is out of range for month
#
# The above exception was the direct cause of the following exception:
#
# DateParseError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 amtrak_df['Month'] = pd.to_datetime(amtrak_df['Month'])
#       2 amtrak_df['Month'] = pd.to_datetime(amtrak_df['Month'])
#       3 amtrak_df.set_index('Month', inplace=True)
#
# ...

# %%
amtrak_df.dtypes
# Out:
# Month                object
# Ridership           float64
# Date         datetime64[ns]
# dtype: object

# %%
amtrak_df.head()
# Out:
#     Month  Ridership Date
# 0  Jan-91   1708.917  NaT
# 1  Feb-91   1620.586  NaT
# 2  Mar-91   1972.715  NaT
# 3  Apr-91   1811.665  NaT
# 4  May-91   1974.964  NaT

# %%
ridership_ts = pd.Series(amtrak_df.Ridership.values, index=amtrak_df.Date)

# %%
ridership_ts
# Out:
# Date
# NaT    1708.917
# NaT    1620.586
# NaT    1972.715
# NaT    1811.665
# NaT    1974.964
#          ...
# NaT         NaN
# NaT         NaN
# NaT         NaN
# NaT         NaN
# NaT         NaN
# Length: 255, dtype: float64
